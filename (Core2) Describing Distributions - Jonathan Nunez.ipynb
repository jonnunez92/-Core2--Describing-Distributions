# %% [markdown]
# # Assignment
# - Analyze and Visualize features:
#     - VitD_levels
#     - Doc_visits
#     - TotalCharge
# ***
# **For each feature listed:**
#
# 1. Plot a histogram with a kde (kernel density estimate)
#     - Add a line for the mean (red)
#     - Add a line for the median (green)
#     - Add a line for for +1 std from the mean (black)
#     - Add a line for the - 1 std from the mean (black)
#     - Highlight the range between +1 and =1 std (yellow)
# 2. Answer the following questions:
#     - Is it Discrete or Continuous?
#     - Does it have a skew? If so, which direction (+/-)
#     - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %% [markdown]
# # Load Libraries/Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Data/data.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
(df.columns).sort_values()
# Out:
# Index(['Additional_charges', 'Age', 'Allergic_rhinitis', 'Anxiety', 'Area',
#        'Arthritis', 'Asthma', 'BackPain', 'Children', 'Complication_risk',
#        'Diabetes', 'Doc_visits', 'Full_meals_eaten', 'Gender', 'HighBlood',
#        'Hyperlipidemia', 'Income', 'Initial_admin', 'Initial_days', 'Lat',
#        'Lng', 'Marital', 'Overweight', 'ReAdmis', 'Reflux_esophagitis',
#        'Services', 'Soft_drink', 'State', 'Stroke', 'TotalCharge',
#        'VitD_levels', 'vitD_supp'],
#       dtype='object')

# %% [markdown]
# # **VitD_levels**

# %% [markdown]
# ## 1. Histogram with KDE

# %%
col = 'VitD_levels'
feature = df[col]

mean = feature.mean()
median = feature.median()
std = feature.std()

plus1_std = mean + std
minus1_std = mean - std

fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax, stat='probability', kde=True)

ax.axvline(mean, color='red', label=f'Mean = {mean:,.2f}' )
ax.axvline(median, color='green', ls = '--', label=f'Median = {median:,.2f}')
ax.axvline(plus1_std, color = 'black',label=f'+1 std = {plus1_std:,.2f}')
ax.axvline(minus1_std, color = 'black', label = f'-1 std = {minus1_std:,.2f}')
ax.axvspan(plus1_std, minus1_std, color = 'yellow', zorder = 0)

ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# ## 2. Questions
#
# 1. **Is it Discrete or Continuous?**
#     - Continuous since there are no spaces in between bins.
# ***
# 2. **Does it have a skew? If so, which direction (+/-)**
#     - No Skew, mean and median are pretty much the same
# ***
# 3. **What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)**
#     - Seems to be Mesokurtic since kurtosis is 3.01

# %% [markdown]
# # **Doc_visits**

# %% [markdown]
# ## 1. Histogram with KDE

# %%
col = 'Doc_visits'
feature = df[col]

mean = feature.mean()
median = feature.median()
std = feature.std()

plus1_std = mean + std
minus1_std = mean - std

fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax, stat='probability', kde=True)

ax.axvline(mean, color='red', label=f'Mean = {mean:,.2f}' )
ax.axvline(median, color='green', ls = '--', label=f'Median = {median:,.2f}')
ax.axvline(plus1_std, color = 'black',label=f'+1 std = {plus1_std:,.2f}')
ax.axvline(minus1_std, color = 'black', label = f'-1 std = {minus1_std:,.2f}')
ax.axvspan(plus1_std, minus1_std, color = 'yellow', zorder = 0)

ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# ## 2. Questions
#
# 1. **Is it Discrete or Continuous?**
#     - Discrete; bins are separate
# ***
# 2. **Does it have a skew? If so, which direction (+/-)**
#     - No skew, mean and median are the same
# ***
# 3. **What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)**
#     - Mesokurtic; kurtosis is 2.99

# %% [markdown]
# # **TotalCharge**

# %% [markdown]
# ## 1. Histogram with KDE

# %%
col = 'TotalCharge'
feature = df[col]

mean = feature.mean()
median = feature.median()
std = feature.std()

plus1_std = mean + std
minus1_std = mean - std

fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax, stat='probability', kde=True)

ax.axvline(mean, color='red', label=f'Mean = {mean:,.2f}' )
ax.axvline(median, color='green', ls = '--', label=f'Median = {median:,.2f}')
ax.axvline(plus1_std, color = 'black',label=f'+1 std = {plus1_std:,.2f}')
ax.axvline(minus1_std, color = 'black', label = f'-1 std = {minus1_std:,.2f}')
ax.axvspan(plus1_std, minus1_std, color = 'yellow', zorder = 0)

ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# ## 2. Questions
#
# 1. **Is it Discrete or Continuous?**
#     - Continuous; bins are not separate
# ***
# 2. **Does it have a skew? If so, which direction (+/-)**
#     - Seems like a positive skew; weighted to the left side
# ***
# 3. **What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)**
#     - Leptokurtic; kurtosis is 3.27
